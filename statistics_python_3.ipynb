# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns

# %%
sample_mean = 110
population_mean = 100
population_std = 15
sample_size = 50
alpa = 0.05

# %%
confidence_intervel = 1 - 0.05

# %%
confidence_intervel
# Out:
# 0.95

# %%
z_score = (sample_mean - population_mean)/(population_std/np.sqrt(50))

# %%
z_score
# Out:
# 4.714045207910317

# %%
z_critical = stats.norm.ppf(confidence_intervel)

# %%
if z_score>z_critical:
    print('reject the null hypothesis')
else:
    print('fail to reject the null hypothesis')
# Out:
# reject the null hypothesis

# %%
p_value = 1 - 0.9999966

# %%
if p_value < alpa:
    print('reject the null hypothesis')
else:
    print('fail to reject the null hypothesis')
# Out:
# reject the null hypothesis

# %%
from numpy.random import randn

# %%
my_data = randn(500)

# %%
my_data
# Out:
# array([ 1.85920994, -0.94845825,  1.56179254,  0.40775328, -1.72974021,
#        -0.74510855, -1.02174501,  0.59326018,  3.08814099,  0.2598374 ,
#         1.10738948, -0.37903691, -0.63818789, -0.08896987, -1.45570609,
#         0.68885046, -0.81792392,  0.85651013,  0.37555879, -1.64379715,
#         0.98114167,  1.81814885, -0.29192627, -0.33665798,  0.9704208 ,
#        -0.29778706,  0.97501963, -0.05424165,  0.35362232,  0.28007759,
#        -0.19546363,  0.71738842,  0.54416325,  0.5837623 ,  0.40527922,
#        -0.1564876 , -1.01460184,  0.59758523,  0.0196984 , -1.57569167,
#        -1.40854546, -1.81158597,  2.60679194,  0.57720986, -1.59639031,
#        -0.8962357 , -0.23734135,  1.21915312,  1.36994395, -0.20197949,
#         0.08153912,  0.17415483,  0.40678918, -0.59181825, -1.75376224,
#         0.64434053, -1.40751222,  0.08358879, -0.94584769,  0.44587275,
#         0.56542665,  0.74414279, -0.17256997, -0.83879608, -0.40201164,
#         2.01323437, -0.10092729,  0.61612558,  1.47303662, -0.28477318,
#         1.50853435,  0.97757446, -0.68834323, -0.66278209, -1.02858691,
#         1.44591552,  1.23723128, -0.21968505, -0.35102493,  0.59643822,
#         1.85279914,  0.82375041, -1.26325461, -1.46122457,  0.94207956,
#         0.65165233,  1.01092642,  0.16252012, -0.43028089,  0.90528359,
#        -0.00340601, -1.73326645,  0.34619742, -1.90463968, -0.84315721,
#        -0.70591321, -1.26135623,  0.87727418,  1.06249324,  0.10014329,
#        -0.71229694,  0.0580034 , -1.08546968, -0.78123649, -0.17269272,
#        -0.48509243, -1.45206893, -0.16376662,  1.13352075, -0.33149224,
#        -0.96366883,  0.11099043, -0.25109906, -0.46314353, -0.19515425,
#        -0.87883703, -1.22047985, -2.91539721, -0.15348132, -1.5040531 ,
#        -0.66007779, -0.36649552, -0.33879056, -0.25767077,  0.12377361,
#        -0.65692974,  0.02251955,  0.1067742 ,  1.48456572, -0.63182489,
#        -0.15361374, -1.68450777, -1.17228533, -0.39834369,  0.3621548 ,
py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(my_data)
# <Axes: ylabel='Density'>

# %%
stats.normaltest(my_data)
# Out:
# NormaltestResult(statistic=0.08148503917723518, pvalue=0.9600762989662595)

# %%
alpha =0.05
CI = 0.95

# %%
sample_mean_iq=110
mean_population=100
population_std=15

# %%
data = population_std*randn(50)+sample_mean_iq

# %%
data
# Out:
# array([126.56948256, 119.07797171, 111.54646016,  93.09558811,
#        103.3267706 , 115.82381906, 104.76695069, 118.69257699,
#         85.69101893,  99.98836102, 133.20372987, 121.20218867,
#         82.88530738, 138.61558685, 114.0302192 , 108.09184284,
#        124.11290691, 135.79476442, 105.87030052, 101.45116269,
#        108.19200818, 120.16594567,  96.79942303, 101.50320617,
#        111.09862558, 127.99106641, 110.93710879, 115.93277041,
#        125.74042649, 114.76552339,  87.54488683, 117.93715499,
#         77.97447909,  80.5840662 , 119.46990972, 105.42505871,
#        125.73172337, 108.30384888, 124.46331229, 112.38444641,
#        107.56200704, 119.02367624, 115.7042167 , 138.24108721,
#        136.05091647,  79.00143034, 107.51680708, 123.4394221 ,
#        109.28826213, 100.9882051 ])

# %%
np.mean(data)
# Out:
# 111.47196060406147

# %%
np.std(data)
# Out:
# 15.130031781834175

# %%
null_hypothesis = mean_population

# %%
from statsmodels.stats.weightstats import ztest
ztest(data,value = null_hypothesis,alternative = 'larger')
# Out:
# (5.3075714173215855, 5.554774131084194e-08)

# %%
if p_value < alpha:
    print('reject the null hypothesis')
else:
    print('fail to reject the null_hypothesis')
# Out:
# reject the null hypothesis

# %%
one-sample t test(with respect to one independent sample)
two- sample t test(with respect to two independent sample)
paried t-test(two sample from the same populatoin on a different time interval)

# %%
my_cricket_score=[22,38,19,15,48,11,10,49,47,38,10,25,46,10,21,24,29,36,25,25]

# %%
len(my_cricket_score)
# Out:
# 20

# %%
np.mean(my_cricket_score)
# Out:
# 27.4

# %%
sample_mean = 27.4

# %%
null_hyphothesis=>>population mean/true=sample mean
# Out:
#   Cell In[88], line 1
#     null_hyphothesis=>>population mean/true=sample mean
#                      ^
# SyntaxError: invalid syntax

# %%
import scipy
result =  scipy.stats.ttest_1samp(my_cricket_score,15)

# %%
result
# Out:
# TtestResult(statistic=4.131642363779888, pvalue=0.0005672503150661017, df=19)

# %%
p_value = result[1]

# %%
if p_value <=0.05:
    print('reject the null hypothesis')
else:
    print('accept the null hypothesis')
# Out:
# reject the null hypothesis

# %%
scipy.stats.ttest_1samp(my_cricket_score,27.4)
# Out:
# TtestResult(statistic=0.0, pvalue=1.0, df=19)

# %%
p_value = scipy.stats.ttest_1samp(my_cricket_score,26)[1]

# %%
p_value
# Out:
# 0.6461790490703262

# %%
if p_value <= 0.05:
    print('reject the null hyphothesis')
else:
    print('accept the null hypothesis')
# Out:
# accept the null hypothesis

# %%
#two_sample t test(with the respect to two independent sample)
my_cricket_score = [22, 38, 29, 45, 48, 41, 40, 49, 47, 38, 20, 45, 46, 50, 21, 44, 29,36, 25, 24]

virat_cricket_score=[33, 45, 23, 25, 46, 46, 46, 49, 49, 44, 44, 49, 25, 31, 25, 40, 30,20, 42 , 37]

# %%
first_sample_mean = np.mean(my_cricket_score)

# %%
first_sample_mean
# Out:
# 36.85

# %%
second_sample_mean = np.mean(virat_cricket_score)

# %%
second_sample_mean
# Out:
# 37.45

# %%
my_null_hypothesis = both sample mean will be equal

# %%
t_stats,pvalue = scipy.stats.ttest_ind(my_cricket_score,virat_cricket_score)

# %%
p_value
# Out:
# 0.6461790490703262

# %%
if p_value <=0.05:
    print('reject the null hypothesis')
else:
    print('accept the null hypothesis')
# Out:
# accept the null hypothesis

# %%
import random
population =[]
for i in range (1,51):
    population.append(random.randint(10,80))

# %%
len(population)
# Out:
# 50

# %%
my_cricket_score_from_first_inning = np.random.choice(population,size=20)
my_cricket_score_from_second_inning = np.random.choice(population,size=20)

# %%
# paired sample t test
# take a sample from sample population on different time interval

print(my_cricket_score_from_first_inning)
print(my_cricket_score_from_second_inning)
# Out:
# [13 25 62 80 44 51 32 10 63 10 80 79 21 44 60 45 60 24 45 44]
# [35 16 67 58 55 50 13 54 80 27 33 62 53 24 79 33 53 16 80 49]

# %%
np.mean(my_cricket_score_from_first_inning)
# Out:
# 44.6

# %%
np.mean(my_cricket_score_from_second_inning)
# Out:
# 46.85

# %%
#my_null_hypothesis = both sample mean will be equal

# %%
t_stats,p_value=scipy.stats.ttest_rel(my_cricket_score_from_first_inning,my_cricket_score_from_second_inning)

# %%
p_value
# Out:
# 0.6620783110681192

# %%
if p_value <= 0.05:
    print('reject the null hypothesis')
else:
    print('accept the null hypothesis')
# Out:
# accept the null hypothesis

# %% [markdown]
# # The weights of 25 obese people were taken before enrolling them into the nutrition camp. The population mean weight is found to be 45 kg before starting the camp. After finishing the camp, for the same 25 people, the sample mean was found to be 75 with a standard deviation of 25. Did the fitness camp work?

# %%
#n = 25
#u = 45
#x = 75
#std = 25

# %%
#null hypothesis
h0 ===> mu45(sample mean is a true / population mean)

# %%
h1 ===> mu ! = 45 (two tail test)(sample mean is not a true/population mean)

# %%
n = 25 
population_mean = 45
sample_mean = 75
sample_std = 25

# %%
t_stats=(sample_mean-population_mean)/(sample_std/np.sqrt(n))

# %%
t_stats
# Out:
# 6.0

# %%
sample_mean - population_mean
# Out:
# 30

# %%
df = n-1

# %%
df
# Out:
# 24

# %%
alpha = 0.05

# %%
CI = 0.95

# %%
critical_value = stats.t.ppf(CI,df)

# %%
critical_value
# Out:
# 1.7108820799094275

# %%
print('t-stats',t_stats)
print('crtical value',critical_value)
# Out:
# t-stats 6.0
# crtical value 1.7108820799094275

# %%
p_value = 1-stats.t.cdf(t_stats,df)

# %%
p_value
# Out:
# 1.703654035845048e-06
